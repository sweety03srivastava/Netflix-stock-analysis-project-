# %% [markdown]
# # Netflix stock analysis project

# %% [markdown]
# # objective:
# 1) volume of stock traded
# 2) Netflix stock price- high , open, close
# 3) Netflix stock price - day, month , yearwise
# 4) top 5 dates with highest stock price
# 5) top 5 dates with lowest stock price

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
import numpy as np
from datetime import datetime

# %%
df = pd.read_csv("NFLX.csv")

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1     2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2     2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3     2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4     2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
# ...          ...         ...         ...         ...         ...         ...
# 1002  2019-12-10  296.119995  298.940002  292.019989  293.119995  293.119995
# 1003  2019-12-11  294.489990  299.429993  294.200012  298.929993  298.929993
# 1004  2019-12-12  295.670013  299.170013  295.059998  298.440002  298.440002
# 1005  2019-12-13  298.500000  301.799988  297.250000  298.500000  298.500000
# 1006  2019-12-16  300.850006  305.709991  298.630005  304.209991  304.209991
#
#         Volume
# 0     13181000
# ...

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 1  2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2  2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 3  2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 4  2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#      Volume
# 0  13181000
# 1  17284900
# 2  17948100
# 3  11670000
# 4   9689000

# %% [markdown]
# # set date as index

# %%
sns.set(rc = {'figure.figsize':(10,5)})

# %%
df['Date']= pd.to_datetime(df['Date'])
df = df.set_index('Date')
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
#
#               Volume
# Date
# 2015-12-16  13181000
# 2015-12-17  17284900
# 2015-12-18  17948100
# 2015-12-21  11670000
# 2015-12-22   9689000

# %% [markdown]
# # volume of stock traded
# x axis pe index chhahiye and y axis pe volume

# %%
sns.lineplot(x = df.index, y = df['Volume'], label = 'volume')
plt.title("relationship between volume of stock and time")
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'relationship between volume of stock and time')

# %% [markdown]
# # Netflix stock price- high , open, close

# %%
df.plot (y =['Open', 'High','Close'],title = "Netlix stock price")
# Out:
# <Axes: title={'center': 'Netlix stock price'}, xlabel='Date'>

# %% [markdown]
# # Netflix stock price - day, month , yearwise

# %%
fig,(ax1,ax2,ax3)= plt.subplots(3, figsize = (15,10))
df.groupby(df.index.day).mean().plot(y = 'Volume', ax = ax1, xlabel = 'day')
df.groupby(df.index.month).mean().plot(y = 'Volume',ax = ax2, xlabel = 'month')
df.groupby(df.index.year).mean().plot(y = 'Volume', ax = ax3, xlabel = 'year')
# Out:
# <Axes: xlabel='year'>

# %% [markdown]
# # top 5 dates with highest stock price

# %%
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2015-12-16  119.800003  123.000000  118.089996  122.639999  122.639999
# 2015-12-17  123.970001  126.349998  122.419998  122.510002  122.510002
# 2015-12-18  120.849998  122.190002  117.919998  118.019997  118.019997
# 2015-12-21  119.510002  119.589996  115.660004  116.629997  116.629997
# 2015-12-22  117.300003  117.430000  114.860001  116.239998  116.239998
# ...                ...         ...         ...         ...         ...
# 2019-12-10  296.119995  298.940002  292.019989  293.119995  293.119995
# 2019-12-11  294.489990  299.429993  294.200012  298.929993  298.929993
# 2019-12-12  295.670013  299.170013  295.059998  298.440002  298.440002
# 2019-12-13  298.500000  301.799988  297.250000  298.500000  298.500000
# 2019-12-16  300.850006  305.709991  298.630005  304.209991  304.209991
#
#               Volume
# Date
# 2015-12-16  13181000
# 2015-12-17  17284900
# 2015-12-18  17948100
# ...

# %%
a = df.sort_values(by = 'High',ascending = False).head(5)
a['High']
# Out:
# Date
# 2018-06-21    423.209991
# 2018-06-22    420.500000
# 2018-07-11    419.769989
# 2018-06-20    419.470001
# 2018-07-10    419.440002
# Name: High, dtype: float64

# %% [markdown]
# # top 5 dates with lowest stock price

# %%
a = df.sort_values(by = 'Low', ascending = True).head(5)
a['Low']
# Out:
# Date
# 2016-02-08    79.949997
# 2016-02-09    81.550003
# 2016-02-05    81.860001
# 2016-02-11    82.910004
# 2016-07-19    84.500000
# Name: Low, dtype: float64

# %% [markdown]
# # graph for high low price

# %%
fig,axes= plt.subplots(nrows = 1, ncols = 2,sharex = True, figsize = (12,5))
fig.suptitle('high and low stock per period od time', fontsize = 18)
sns.lineplot(ax = axes[0], y = df['High'], x = df.index,color = 'green')
sns.lineplot(ax = axes[1], y = df['Low'], x = df.index, color = 'red')
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
